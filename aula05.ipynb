# %%
import pandas as pd
import numpy as np

table = pd.read_csv('./fileaula05.csv')
table
# Out:
#       nome      telefone              email sexo
# 0   Ismael  5.585000e+07   ismael@gmail.com    M
# 1  Gabriel           NaN  gabriel@gmail.com    M
# 2    Jenni  5.585000e+07    jenni@gmail.com    F
# 3     José  8.599100e+07                NaN    M
# 4      Gio           NaN      gio@gmail.com    F
# 5  Emanuel  8.590330e+05  emanuel@gmail.com    M
# 6  Ronaldo           NaN                NaN    M
# 7    Julio  8.599102e+11    julio@gmail.com    M
# 8      Eli  8.592109e+08                NaN    M

# %%
table.head(5)
# Out:
#       nome    telefone              email sexo
# 0   Ismael  55850000.0   ismael@gmail.com    M
# 1  Gabriel         NaN  gabriel@gmail.com    M
# 2    Jenni  55850000.0    jenni@gmail.com    F
# 3     José  85991000.0                NaN    M
# 4      Gio         NaN      gio@gmail.com    F

# %%
table.tail(4)
# Out:
#       nome      telefone              email sexo
# 5  Emanuel  8.590330e+05  emanuel@gmail.com    M
# 6  Ronaldo           NaN                NaN    M
# 7    Julio  8.599102e+11    julio@gmail.com    M
# 8      Eli  8.592109e+08                NaN    M

# %%
table.iloc[3:6]
# Out:
#       nome    telefone              email sexo
# 3     José  85991000.0                NaN    M
# 4      Gio         NaN      gio@gmail.com    F
# 5  Emanuel    859033.0  emanuel@gmail.com    M

# %%
table.loc[(table['nome'] == 'Ismael')]
# Out:
#      nome    telefone             email sexo
# 0  Ismael  55850000.0  ismael@gmail.com    M

# %%
table.sort_values(by=['nome'])
# Out:
#       nome      telefone              email sexo
# 8      Eli  8.592109e+08                NaN    M
# 5  Emanuel  8.590330e+05  emanuel@gmail.com    M
# 1  Gabriel           NaN  gabriel@gmail.com    M
# 4      Gio           NaN      gio@gmail.com    F
# 0   Ismael  5.585000e+07   ismael@gmail.com    M
# 2    Jenni  5.585000e+07    jenni@gmail.com    F
# 3     José  8.599100e+07                NaN    M
# 7    Julio  8.599102e+11    julio@gmail.com    M
# 6  Ronaldo           NaN                NaN    M

# %%
table.isnull()
# Out:
#     nome  telefone  email   sexo
# 0  False     False  False  False
# 1  False      True  False  False
# 2  False     False  False  False
# 3  False     False   True  False
# 4  False      True  False  False
# 5  False     False  False  False
# 6  False      True   True  False
# 7  False     False  False  False
# 8  False     False   True  False

# %%
table.describe()
# Out:
#            telefone
# count  6.000000e+00
# mean   1.434947e+11
# std    3.509707e+11
# min    8.590330e+05
# 25%    5.585000e+07
# 50%    7.092050e+07
# 75%    6.659059e+08
# max    8.599102e+11

# %%
table.shape
# Out:
# (9, 4)

# %%
table.dtypes
# Out:
# nome         object
# telefone    float64
# email        object
# sexo         object
# dtype: object
